# %% [markdown]
# #Tugas Eksplorasi Library Face Detection#
# Library yang digunakan adalah Deep face Library, kode sumber https://github.com/serengil/deepface
#
# Tim Kelompok :
# 1.   33221311 - Meredita Susanty
# 2.   33221036 - Mina Ismu Rahayu

# %% [markdown]
# ###Install Deep Face Library###

# %%
# !pip install deepface
# Out:
# ...
#      |████████████████████████████████| 65 kB 3.2 MB/s
# ...
#      |████████████████████████████████| 60.5 MB 1.1 MB/s
# ...
#      |████████████████████████████████| 87 kB 8.5 MB/s
# ...
#      |████████████████████████████████| 2.3 MB 56.4 MB/s
# ...
#      |████████████████████████████████| 462 kB 65.5 MB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115942 sha256=78f948b9862aa1e043c43c88bd7b52325bee33944a5881a3c7c3b51f27c33a1f
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built fire
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %% [markdown]
# ###Import library ###
# 1.   Deep Face Library (Library Deep Face)
# 2.   Open CV (Image Processing)
# 1.   Matplotlib (Visualisasi image)

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %% [markdown]
# ###Download dataset Gambar###
# Folder terdiri dari
# 1.   Anggota Kelas
# 2.   non-anggota kelas

# %%
# !git clone https://github.com/namura/DatasetPML/
# Out:
# Cloning into 'DatasetPML'...
# remote: Enumerating objects: 154, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 154 (delta 0), reused 9 (delta 0), pack-reused 145
# Receiving objects: 100% (154/154), 79.17 MiB | 31.32 MiB/s, done.

# %% [markdown]
# Menampilkan seluruh dataset Anggota kelas yang diambil dari folder Anggota kelas

# %%
import os
from pathlib import Path
folder1 = '/content/DatasetPML/Anggota Kelas'

def load_images_from_folder(folder):
    images = []
    labels=[]    
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        #if img is not None:
        images.append(img)
        labels.append(Path(filename).stem)
    return images,labels
x,lbl=load_images_from_folder(folder1)
countData=len(x)

# %%
plt.figure(figsize=(10,10))
for i in range(countData):
    plt.subplot(10,10,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x[i][:, :, ::-1 ])
    plt.xlabel(lbl[i])
plt.show()

# %% [markdown]
# Menampilkan seluruh dataset non Anggota kelas yang diambil dari folder non-anggota kelas

# %%
import os
folder2 = '/content/DatasetPML/non-anggota kelas'

def load_images_from_folder(folder):
    images = []
    labels=[]
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        #if img is not None:
        images.append(img)
        labels.append(Path(filename).stem)
    return images,labels
x2,lbl2=load_images_from_folder(folder2)
countData2=len(x2)

# %%
plt.figure(figsize=(10,10))
for i in range(countData2):
    plt.subplot(10,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x2[i][:, :, ::-1 ])
    plt.xlabel(lbl2[i])  
plt.show()

# %% [markdown]
# ###Model###
# Model yang dapat digunakan dalam DFL terdiri dari
# [VGG-Face](https://sefiks.com/2018/08/06/deep-face-recognition-with-keras/), [Google FaceNet](https://sefiks.com/2018/09/03/face-recognition-with-facenet-in-keras/), [OpenFace](https://sefiks.com/2019/07/21/face-recognition-with-openface-in-keras/), [Facebook DeepFace](https://sefiks.com/2020/02/17/face-recognition-with-facebook-deepface-in-keras/), [DeepID](https://sefiks.com/2020/06/16/face-recognition-with-deepid-in-keras/), [ArcFace](https://sefiks.com/2020/12/14/deep-face-recognition-with-arcface-in-keras-and-python/), [Dlib](https://sefiks.com/2020/07/11/face-recognition-with-dlib-in-python/) and SFace.
#
# kita akan mencoba 3 model yaitu VGG-Face, google Facenet dan Facebook Deepface

# %%
#contoh memanggil model VGGFace
model_name = "VGG-Face"
model = DeepFace.build_model(model_name)
# Out:
# vgg_face_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: /root/.deepface/weights/vgg_face_weights.h5
# 100%|██████████| 580M/580M [01:18<00:00, 7.42MB/s]

# %%
#contoh memanggil model Facenet
model_name = "Facenet"
model = DeepFace.build_model(model_name)
# Out:
# facenet_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facenet_weights.h5
# To: /root/.deepface/weights/facenet_weights.h5
# 100%|██████████| 92.2M/92.2M [00:00<00:00, 320MB/s]

# %%
#contoh memanggil model Facebook Deep Face
model_name = "DeepFace"
model = DeepFace.build_model(model_name)
# Out:
# VGGFace2_DeepFace_weights_val-0.9034.h5 will be downloaded...
# Downloading...
# From: https://github.com/swghosh/DeepFace/releases/download/weights-vggface2-2d-aligned/VGGFace2_DeepFace_weights_val-0.9034.h5.zip
# To: /root/.deepface/weights/VGGFace2_DeepFace_weights_val-0.9034.h5.zip
# 100%|██████████| 511M/511M [00:30<00:00, 16.9MB/s]

# %% [markdown]
# ###Detectors###
# DFL Menyediakan beberapa library detectors yang berfungsi untuk melakukan deteksi wajah dan melakukan crop terhadap bounding wajah yang terdeteksi, library detector yang disediakan terdiri dari :
#
# 1.   opencv
# 2.   ssd
# 1.   mtcnn
# 2.   dlib
# 1.   retinaface
#
# default detectors DFL yaitu opencv, untuk proses komputasi opencv memiliki kecepatan yang baik, hanya saja untuk hasil verifikasi dan identifikasi yang lebih baik retinaface lebih disarankan walaupun membutukan proses komputasi yang lebih berat.

# %%
import numpy as np
class_names = np.array([
    'original',
    'Opencv',
    'ssd',
    'mtcnn',
    'dlib',
    'retinaface'])

detectors = ["opencv", "ssd", "mtcnn", "dlib", "retinaface"]
gambar=[]
gambar.append(cv2.imread('/content/DatasetPML/Anggota Kelas/Mina Ismu Rahayu (3).jpg'))
gambar.append(DeepFace.detectFace(img_path = gambar[0], target_size = (224, 224), detector_backend = detectors[0]))
gambar.append(DeepFace.detectFace(img_path = gambar[0], target_size = (224, 224), enforce_detection=False,detector_backend = detectors[1]))
gambar.append(DeepFace.detectFace(img_path = gambar[0], target_size = (224, 224), enforce_detection=False,detector_backend = detectors[2]))
gambar.append(DeepFace.detectFace(img_path = gambar[0], target_size = (224, 224), enforce_detection=False,detector_backend = detectors[3]))
gambar.append(DeepFace.detectFace(img_path = gambar[0], target_size = (224, 224), enforce_detection=False,detector_backend = detectors[4]))
# Out:
# deploy.prototxt will be downloaded...
# Downloading...
# From: https://github.com/opencv/opencv/raw/3.4.0/samples/dnn/face_detector/deploy.prototxt
# To: /root/.deepface/weights/deploy.prototxt
# 28.1kB [00:00, 11.8MB/s]
# res10_300x300_ssd_iter_140000.caffemodel will be downloaded...
# Downloading...
# From: https://github.com/opencv/opencv_3rdparty/raw/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel
# To: /root/.deepface/weights/res10_300x300_ssd_iter_140000.caffemodel
# 100%|██████████| 10.7M/10.7M [00:00<00:00, 168MB/s]
# Downloading...
# From: http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# To: /root/.deepface/weights/shape_predictor_5_face_landmarks.dat.bz2
# shape_predictor_5_face_landmarks.dat.bz2 is going to be downloaded
# 100%|██████████| 5.71M/5.71M [00:00<00:00, 7.86MB/s]
# retinaface.h5 will be downloaded from the url https://github.com/serengil/deepface_models/releases/download/v1.0/retinaface.h5
# Downloading...
# ...

# %%
plt.figure(figsize=(10,10))
for i in range(len(gambar)):
    plt.subplot(1,6,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(gambar[i])
    plt.xlabel(class_names[i])
plt.show()

# %% [markdown]
# Untuk membuktikan hasil perbandingan detektor, akan dilakukan verifikasi kesamaan gambar dengan objek yg sama dengan gambar yang berbeda

# %%
images=[]
data1='/content/DatasetPML/Anggota Kelas/Mina Ismu Rahayu(1).jpg'
data2='/content/DatasetPML/Anggota Kelas/Mina Ismu Rahayu (3).jpg'
images.append(cv2.imread(data1))
images.append(cv2.imread(data2))
images.append(DeepFace.detectFace(img_path = data1, target_size = (224, 224), detector_backend = detectors[0]))
plt.figure(figsize=(5,5))
for i in range(2):
    plt.subplot(1,2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(images[i][:, :, ::-1 ])#-1 untuk nilai satruasi gambar
plt.show()

# %%
#menggunakan detectors opencv
detectors = ["opencv", "ssd", "mtcnn", "dlib", "retinaface"]
result = DeepFace.verify(images[0],images[1], detector_backend=detectors[0])
result
#salah karena hasil False atau tidak sama
# Out:
# {'detector_backend': 'opencv',
#  'distance': 0.562273903974924,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine',
#  'threshold': 0.4,
#  'verified': False}

# %%
#menggunakan detectors retinaface
detectors = ["opencv", "ssd", "mtcnn", "dlib", "retinaface"]
result = DeepFace.verify(images[0],images[1], detector_backend=detectors[4])
result
#benar karena hasil True
# Out:
# {'detector_backend': 'retinaface',
#  'distance': 0.1914371657205738,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine',
#  'threshold': 0.4,
#  'verified': True}

# %%
#menggunakan detectors mtcnn
detectors = ["opencv", "ssd", "mtcnn", "dlib", "retinaface"]
result = DeepFace.verify(images[0],images[1], detector_backend=detectors[2])
result
#benar karena hasil True
# Out:
# {'detector_backend': 'mtcnn',
#  'distance': 0.1593630927915357,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine',
#  'threshold': 0.4,
#  'verified': True}

# %% [markdown]
# berdasarkan contoh gambar diatas fungsi detektor sangat penting untuk menentukan bounding objek wajah yang akan dideteksi. Detector opencv untuk kasus diatas tidak sesuai dengan visual manusia

# %%
#membandingkan 2 objek berbeda 
images=[]
data1='/content/DatasetPML/Anggota Kelas/Mina Ismu Rahayu (3).jpg'
data2='/content/DatasetPML/Anggota Kelas/meredita susanty.jpg'
images.append(cv2.imread(data1))
images.append(cv2.imread(data2))

plt.figure(figsize=(5,5))
for i in range(2):
    plt.subplot(1,2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(images[i][:, :, ::-1 ])
plt.show()

# %%
#menggunakan Model Facenet detectors ssd
detectors = ["opencv", "ssd", "mtcnn", "dlib", "retinaface"]
result = DeepFace.verify(images[0],images[1], detector_backend=detectors[1],model_name="Facenet")
result
#benar karena hasil False atau tidak sama
# Out:
# {'detector_backend': 'ssd',
#  'distance': 0.41791038199510766,
#  'model': 'Facenet',
#  'similarity_metric': 'cosine',
#  'threshold': 0.4,
#  'verified': False}

# %%
#menggunakan Model VGG-Face detectors ssd
detectors = ["opencv", "ssd", "mtcnn", "dlib", "retinaface"]
result = DeepFace.verify(images[0],images[1], detector_backend=detectors[1],model_name="VGG-Face")
result
#salah karena hasil True atau sama tetapi nilai sangat mendekati threshold
# Out:
# {'detector_backend': 'ssd',
#  'distance': 0.3914590556639319,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine',
#  'threshold': 0.4,
#  'verified': True}

# %%
#menggunakan Model DeepFace detectors ssd
detectors = ["opencv", "ssd", "mtcnn", "dlib", "retinaface"]
result = DeepFace.verify(images[0],images[1], detector_backend=detectors[1],model_name="DeepFace")
result
#benar karena hasil false atau tidak sama
# Out:
# {'detector_backend': 'ssd',
#  'distance': 0.32960021941729023,
#  'model': 'DeepFace',
#  'similarity_metric': 'cosine',
#  'threshold': 0.23,
#  'verified': False}

# %%
#menggunakan model VGG-Face detectors dlib
detectors = ["opencv", "ssd", "mtcnn", "dlib", "retinaface"]
result = DeepFace.verify(images[0],images[1], detector_backend=detectors[3])
result
#salah karena hasil True atau sama dan nilai jauh dari treshold
# Out:
# {'detector_backend': 'dlib',
#  'distance': 0.3399652787935703,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine',
#  'threshold': 0.4,
#  'verified': True}

# %%
#menggunakan model DeepFace detectors dlib
detectors = ["opencv", "ssd", "mtcnn", "dlib", "retinaface"]
result = DeepFace.verify(images[0],images[1], detector_backend=detectors[3], model_name="DeepFace")
result
#benar karena hasil False atau tidak sama
# Out:
# {'detector_backend': 'dlib',
#  'distance': 0.5307627290475841,
#  'model': 'DeepFace',
#  'similarity_metric': 'cosine',
#  'threshold': 0.23,
#  'verified': False}

# %%
#menggunakan model VGG-Face detectors retinaface
detectors = ["opencv", "ssd", "mtcnn", "dlib", "retinaface"]
result = DeepFace.verify(images[0],images[1], detector_backend=detectors[4])
result
#benar karena hasil False atau tidak sama
# Out:
# {'detector_backend': 'retinaface',
#  'distance': 0.41999765671389966,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine',
#  'threshold': 0.4,
#  'verified': False}

# %%
#menggunakan model DeepFace detectors retinaface
detectors = ["opencv", "ssd", "mtcnn", "dlib", "retinaface"]
result = DeepFace.verify(images[0],images[1], detector_backend=detectors[4], model_name="DeepFace")
result
#Benar karena hasil False atau tidak sama
# Out:
# {'detector_backend': 'retinaface',
#  'distance': 0.39687183752297184,
#  'model': 'DeepFace',
#  'similarity_metric': 'cosine',
#  'threshold': 0.23,
#  'verified': False}

# %% [markdown]
# ###Melakukan pencarian wajah yang sesuai dari suatu dataset kumpulan wajah menggunakan deepface.find###
# percobaan untuk anggota kelas dengan Model google Deep Face dan detectors Retinaface

# %%
#jika ingin mengambil gambar secara langsung menggunakan kamera dapat menjalankan fungsi take_photo
#jika tidak maka dapat melakukan upload datatest kedalam google colab
import imutils
import numpy as np
from google.colab.patches import cv2_imshow
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

# %%
def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
#1. memanggil fungsi take_photo
#file akan tersimpan ke dalam /content/photo.jpg
image_file = take_photo()
image = cv2.imread(image_file)

# resize it to have a maximum width of 400 pixels
image = imutils.resize(image, width=400)
(h, w) = image.shape[:2]
print(w,h)
cv2_imshow(image)
# Out:
# 400 300
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7FA621318510>

# %%
#database db_path=folder1 yaitu data anggota kelas
images=[]
imgtest=image
images.append(imgtest)
detectors = ["opencv", "ssd", "mtcnn", "dlib", "retinaface"]
#fungsi similarity metrics dapat dipilih antara cosine, euclidean dan euclidean_12
#di contoh ini kita menggunakan euclidean
metrics = ["cosine", "euclidean", "euclidean_l2"]
#storing match and ranks by creating a dataframe
df = DeepFace.find(img_path = imgtest, db_path =folder1,enforce_detection=False, distance_metric = metrics[1],detector_backend = detectors[4], model_name="DeepFace") 
result=df[0:5]
r=result['identity']
result
# Out:
# WARNING: Representations for images in  /content/DatasetPML/Anggota Kelas  folder were previously stored in  representations_deepface.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  63  representations found in  representations_deepface.pkl
# find function lasts  0.349118709564209  seconds
#                                             identity  DeepFace_euclidean
# 0  /content/DatasetPML/Anggota Kelas/Mina Ismu Ra...           56.812771
# 1  /content/DatasetPML/Anggota Kelas/m khaerul na...           59.052767
# 2  /content/DatasetPML/Anggota Kelas/Mina Ismu Ra...           61.493978
# 3  /content/DatasetPML/Anggota Kelas/arief sarton...           62.396171
# 4  /content/DatasetPML/Anggota Kelas/meredita sus...           62.593816

# %%
images.append(cv2.imread(r[0]))
plt.figure(figsize=(5,5))
for i in range(2):
    plt.subplot(1,2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(images[i][:, :, ::-1])
plt.show()

# %%
#database db_path=folder2 yaitu data non anggota kelas
images=[]
imgtest=image
images.append(imgtest)
detectors = ["opencv", "ssd", "mtcnn", "dlib", "retinaface"]
metrics = ["cosine", "euclidean", "euclidean_l2"]
#storing match and ranks by creating a dataframe
df = DeepFace.find(img_path = imgtest, db_path =folder2,enforce_detection=False, distance_metric = metrics[1],detector_backend = detectors[4],model_name="DeepFace") 
result=df[0:5]
result
#hasil tidak ada yang sama
# Out:
# WARNING: Representations for images in  /content/DatasetPML/non-anggota kelas  folder were previously stored in  representations_deepface.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_deepface.pkl
# find function lasts  0.3135950565338135  seconds
# Empty DataFrame
# Columns: [identity, DeepFace_euclidean]
# Index: []

# %%
import numpy as np
class_names = np.array([
    'original',
    'Opencv',
    'ssd',
    'mtcnn',
    'dlib',
    'retinaface'])

detectors = ["opencv", "ssd", "mtcnn", "dlib", "retinaface"]
gambar=[]
gambar.append(cv2.imread('/content/dian.jpg'))
gambar.append(DeepFace.detectFace(img_path = gambar[0], target_size = (224, 224), detector_backend = detectors[0]))
gambar.append(DeepFace.detectFace(img_path = gambar[0], target_size = (224, 224), enforce_detection=False,detector_backend = detectors[1]))
gambar.append(DeepFace.detectFace(img_path = gambar[0], target_size = (224, 224), enforce_detection=False,detector_backend = detectors[2]))
gambar.append(DeepFace.detectFace(img_path = gambar[0], target_size = (224, 224), enforce_detection=False,detector_backend = detectors[3]))
gambar.append(DeepFace.detectFace(img_path = gambar[0], target_size = (224, 224), enforce_detection=False,detector_backend = detectors[4]))

# %%
plt.figure(figsize=(10,10))
for i in range(len(gambar)):
    plt.subplot(1,6,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(gambar[i])
    plt.xlabel(class_names[i])
plt.show()

# %%
#berdasarkan hasil detector kita akan mencoba menggunakan detector opencv
detectors = ["opencv", "ssd", "mtcnn", "dlib", "retinaface"]
metrics = ["cosine", "euclidean", "euclidean_l2"]
df = DeepFace.find(img_path = gambar[0], db_path =folder2,enforce_detection=False, distance_metric = metrics[1],detector_backend = detectors[0],model_name="DeepFace") 
result=df[0:5]
result
# Out:
# WARNING: Representations for images in  /content/DatasetPML/non-anggota kelas  folder were previously stored in  representations_deepface.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  18  representations found in  representations_deepface.pkl
# find function lasts  0.21824288368225098  seconds
#                                          identity  DeepFace_euclidean
# 0  /content/DatasetPML/non-anggota kelas/dian.jpg           59.851612

# %%
images=[]
r=result['identity']
images.append(gambar[1])
images.append(cv2.imread(r[0]))
plt.figure(figsize=(5,5))
for i in range(2):
    plt.subplot(1,2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(images[i][:, :, ::-1])
plt.show()

# %%
#selanjutnya cek di anggota kelas / folder 1 
#untuk detector opencv dan retinaface ditemukan dan menggunakan detector dlib tidak ditemukan 
#dlib
detectors = ["opencv", "ssd", "mtcnn", "dlib", "retinaface"]
metrics = ["cosine", "euclidean", "euclidean_l2"]
df = DeepFace.find(img_path = gambar[0], db_path =folder1,enforce_detection=False, distance_metric = metrics[0],detector_backend = detectors[3],model_name="DeepFace") 
result=df[0:5]
result
# Out:
# WARNING: Representations for images in  /content/DatasetPML/Anggota Kelas  folder were previously stored in  representations_deepface.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  63  representations found in  representations_deepface.pkl
# find function lasts  0.3815603256225586  seconds
# Empty DataFrame
# Columns: [identity, DeepFace_cosine]
# Index: []

# %%
#selanjutnya cek di anggota kelas / folder 1 
#untuk detector opencv dan retinaface ditemukan dan menggunakan detector dlib tidak ditemukan 
#opencv
detectors = ["opencv", "ssd", "mtcnn", "dlib", "retinaface"]
metrics = ["cosine", "euclidean", "euclidean_l2"]
df = DeepFace.find(img_path = gambar[0], db_path =folder1,enforce_detection=False, distance_metric = metrics[0],detector_backend = detectors[0],model_name="DeepFace") 
result=df[0:5]
result
# Out:
# WARNING: Representations for images in  /content/DatasetPML/Anggota Kelas  folder were previously stored in  representations_deepface.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  63  representations found in  representations_deepface.pkl
# find function lasts  0.3116292953491211  seconds
#                                             identity  DeepFace_cosine
# 0  /content/DatasetPML/Anggota Kelas/meredita sus...         0.182681
# 1  /content/DatasetPML/Anggota Kelas/Kemas Muhamm...         0.197919
# 2  /content/DatasetPML/Anggota Kelas/m khaerul na...         0.198898
# 3  /content/DatasetPML/Anggota Kelas/Ahmad Luky R...         0.205125
# 4  /content/DatasetPML/Anggota Kelas/Varuliantor-...         0.209644

# %%
images=[]
r=result['identity']
images.append(gambar[1])
images.append(cv2.imread(r[0]))
plt.figure(figsize=(5,5))
for i in range(2):
    plt.subplot(1,2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(images[i][:, :, ::-1])
plt.show()
